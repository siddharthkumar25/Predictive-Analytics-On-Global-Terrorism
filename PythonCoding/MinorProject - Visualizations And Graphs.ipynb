# %% [markdown]
# # Visualizations And Graphs

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# # Importing The Dataset

# %%
data = pd.read_csv("A:/MinorProjectData/GlobalTerrorCleanPartTwo.csv")

# %%
# Make a range of years to show categories with no observations
years = np.arange(1995, 2017)

# Draw a count plot to show the number of attacks each year
plt1 = sns.catplot("iyear", data=data, kind="count", color='red', height=10.6, aspect=1.618)
plt1.set_xticklabels(step=2)
_ = plt.title('Attacks by Year', fontsize = 20)
_ = plt.xlabel('Year', fontsize = 16)
_ = plt.ylabel('Number of Attacks', fontsize = 16)

# %%
# Make a range of years to show categories with no observations
years = np.arange(1995, 2017)

df1 = data[['iyear', 'nkill']]
gp1 = df1.groupby(['iyear'], as_index = False).sum()

# Draw a count plot to show the number of attacks each year
plt1 = sns.catplot(x = 'iyear', y = 'nkill', data=gp1, kind = 'bar', color='steelblue', height=7.6, aspect=1.618)
plt1.set_xticklabels(step=3)
_ = plt.title('Fatalities by Year', fontsize = 20)
_ = plt.xlabel('Year', fontsize = 16)
_ = plt.ylabel('Number of Fatalities', fontsize = 16)
plt.show();

# %%
ax = sns.catplot('attacktype1_txt', data=data, height=7.6, aspect=1.618, kind="count")
ax.set_xticklabels(rotation=90)
ax = plt.ylabel('Count', fontsize=16)
ax = plt.xlabel('',)
ax = plt.title('Total Attacks by Type 1995 - 2017', fontsize=20)

plt.show();

# %%
ax = sns.catplot('weaptype1_txt', data=data, height=7.6, aspect=1.618, kind="count")
ax.set_xticklabels(rotation=90)
ax = plt.ylabel('Count', fontsize=16)
ax = plt.xlabel('',)
ax = plt.title('Total Attacks by Weapon Type 1995 - 2017', fontsize=20)
plt.show();

# %%
graph_trg= sns.catplot('targtype1_txt', data=data, height=7.6, aspect=1.618, kind="count")
graph_trg.set_xticklabels(rotation=90)
graph_trg = plt.ylabel('Count', fontsize=16)
graph_trg = plt.xlabel('',)
graph_trg = plt.title('Target Types : 1995 - 2017', fontsize=20)
plt.show();

# %%
plt.figure(figsize=(14.6, 9.0))
graph_nkill = sns.scatterplot(x=data["iyear"], y=data["nkill"] , legend = 'full')
graph_trg = plt.ylabel('Number Of Kills', fontsize=16)
graph_trg = plt.xlabel('',)
graph_trg = plt.title('Number Of Kills and Weapons Used : 1995 - 2017', fontsize=20)

# %%
data['region_txt'].unique()
# Out:
# array(['Central America & Caribbean', 'North America', 'Southeast Asia',
#        'Western Europe', 'East Asia', 'South America', 'Eastern Europe',
#        'Middle East & North Africa', 'Australasia & Oceania',
#        'South Asia', 'Sub-Saharan Africa', 'Central Asia'], dtype=object)

# %%
plt.figure(figsize=(12,8))
plt.title('South Asia Attacks', fontsize=18)
data[data.region_txt == 'South Asia'].country_txt.value_counts().plot(kind='barh');

# %%
data[data['country_txt'] == 'India']
# Out:
#              eventid  iyear  imonth  iday  extended  country country_txt  \
# 1166    1.972020e+11   1972       2    22         0       92       India
# 2656    1.975010e+11   1975       1     2         0       92       India
# 3726    1.976050e+11   1976       5    26         0       92       India
# 5171    1.977090e+11   1977       9    28         0       92       India
# 7088    1.979010e+11   1979       1    13         0       92       India
# 7092    1.979010e+11   1979       1    14         0       92       India
# 7864    1.979040e+11   1979       4    26         0       92       India
# 8349    1.979060e+11   1979       6    14         0       92       India
# 8489    1.979070e+11   1979       7     1         0       92       India
# 8493    1.979070e+11   1979       7     2         0       92       India
# 8763         6  South Asia            Mizoram   ...
# 8792         6  South Asia            Mizoram   ...
# 8794         6  South Asia          Jharkhand   ...
# 8803         6  South Asia              Delhi   ...
# 8804         6  South Asia              Delhi   ...
# 8812         6  South Asia          Jharkhand   ...
# 8859         6  South Asia         Tamil Nadu   ...
# 8954         6  South Asia            Manipur   ...
# 9394         6  South Asia      Uttar Pradesh   ...
# 9434         6  South Asia            Manipur   ...
# 9502         6  South Asia              Bihar   ...
# 9542         6  South Asia            Manipur   ...
# 9586         6  South Asia            Manipur   ...
# 10088        6  South Asia      Uttar Pradesh   ...
# 10196        6  South Asia        West Bengal   ...
# 10404        6  South Asia              Delhi   ...
# 11274        6  South Asia         Tamil Nadu   ...
# 11791        6  South Asia              Assam   ...
# ...        ...         ...                ...   ...
# 165436       6  South Asia              Delhi   ...
# 165437       6  South Asia            Manipur   ...
# 165438       6  South Asia            Manipur   ...
# 165453       6  South Asia  Jammu and Kashmir   ...
# 165468       6  South Asia           Nagaland   ...
# 165488       6  South Asia             Odisha   ...
# 165520       6  South Asia     Andhra Pradesh   ...
# 165521       6  South Asia        Maharashtra   ...
# 165524       6  South Asia            Manipur   ...
# 165525       6  South Asia            Manipur   ...
# 165526       6  South Asia            Manipur   ...
# 165539       6  South Asia       Chhattisgarh   ...
# 165555       6  South Asia  Jammu and Kashmir   ...
# 165592       6  South Asia           Nagaland   ...
# 165594       6  South Asia            Manipur   ...
# 165611       6  South Asia  Jammu and Kashmir   ...
# 165612       6  South Asia  Jammu and Kashmir   ...
# 165613       6  South Asia  Jammu and Kashmir   ...
# 165614       6  South Asia       Chhattisgarh   ...
# 165618       6  South Asia             Odisha   ...
# 165619       6  South Asia              Bihar   ...
# 165634       6  South Asia              Assam   ...
# 165640       6  South Asia       Chhattisgarh   ...
# 165663       6  South Asia      Uttar Pradesh   ...
# 165681       6  South Asia        Maharashtra   ...
# 165682       6  South Asia        Maharashtra   ...
# 165695       6  South Asia             Odisha   ...
# 165697       6  South Asia          Karnataka   ...
# 165707       6  South Asia  Jammu and Kashmir   ...
# 165721       6  South Asia            Manipur   ...
#
#                      weapsubtype1_txt  nkill  nwound  property  ishostkid  \
# 1166           Unknown Explosive Type      0       0         0          1
# 2656           Unknown Explosive Type      4       0         0          0
# 3726           Unknown Explosive Type      0       0         1          0
# 5171                 Unknown Gun Type      0       0         0          1
# 7088                 Automatic Weapon      0       0         1          0
# 7092                          Handgun      3       0         0          0
# 7864                 Unknown Gun Type      4       0         1          0
# 8349                 Unknown Gun Type      1       0         0          0
# 8489                 Unknown Gun Type      2       2         1          0
# 8493                          Unknown      0       0         1          0
# 8494                          Unknown      0       0         1          0
# 8701                          Unknown      1       1         1          0
# 8763    Rifle/Shotgun (non-automatic)      1       0         0          0
# 8792                 Unknown Gun Type      1       0         0          0
# 8794           Unknown Explosive Type      1       0         1          0
# 8803                 Unknown Gun Type      1       1         1          0
# 8804                 Unknown Gun Type      1       0         1          0
# 8812           Unknown Explosive Type      3      14         1          0
# 8859           Unknown Explosive Type      3       0         1          0
# 8954                 Automatic Weapon      4       0         1          0
# 9394                          Handgun      0       0         0          0
# 9434                          Unknown      1       0         0          0
# 9502                 Automatic Weapon      3       1         1          0
# 9542                          Unknown      1       0         0          0
# 9586                 Automatic Weapon      2       4         1          0
# 10088                         Unknown      4       3         1          0
# 10196          Unknown Explosive Type      2       6         1          0
# 10404   Rifle/Shotgun (non-automatic)      1       0         0          0
# 11274          Unknown Explosive Type      6       0         1          0
# 11791                       Time Fuse      0       0         0          0
# ...                               ...    ...     ...       ...        ...
# 165436               Unknown Gun Type      1       0         0          0
# 165437                        Grenade      0       0        -9          0
# 165438               Unknown Gun Type      0       0         0          0
# 165453                        Grenade      0       0         1          0
# 165468         Unknown Explosive Type      0       3         1          0
# 165488               Unknown Gun Type      1       0         1          0
# 165520                     Arson/Fire      0       0         1          0
# 165521                     Arson/Fire      0       0         1          1
# 165524                     Arson/Fire      0       0         1          0
# 165525                     Arson/Fire      0       0         1          0
# 165526                     Arson/Fire      0       0         1          0
# 165539                      Land Mine      1       0         0          0
# 165555               Unknown Gun Type      1       0         0          0
# 165592         Unknown Explosive Type      0       0         0          0
# 165594                        Grenade      0       0         0          0
# 165611               Unknown Gun Type      0       1         0          0
# 165612               Unknown Gun Type      0       0         0          0
# 165613               Unknown Gun Type      0       0         0          0
# 165614           Other Explosive Type      0       1         0          0
# 165618               Unknown Gun Type      2       0         0          1
# 165619           Other Explosive Type      0       1         1          0
# 165634                        Grenade      0       0         0          0
# 165640               Pressure Trigger      0       1         0          0
# 165663               Unknown Gun Type      0       2         0          0
# 165681                        Unknown      2       0         0          0
# 165682                        Unknown      1       0         0          0
# 165695               Unknown Gun Type      0       1         0          1
# 165697         Unknown Explosive Type      0       0         0          0
# 165707               Unknown Gun Type      1       0         0          0
# 165721         Unknown Explosive Type      0       0         0          0
#
#                                         dbsource  INT_LOG  INT_IDEO  INT_MISC  \
# 1166                                Hijacking DB        1         1         1
# 2656    UMD Encyclopedia of World Terrorism 2012        0         0         0
# 3726                                        PGIS       -9        -9         0
# 5171                                Hijacking DB        1         1         1
# 7088                                        PGIS        0         0         0
# 7092                                        PGIS       -9        -9         0
# 7864                                        PGIS        0         0         0
# 8349                                        PGIS        0         0         0
# 8489                                        PGIS        0         0         0
# 8493                                        PGIS        0         0         0
# 8494                                        PGIS        0         0         0
# 8701                                        PGIS        0         0         0
# 8763                                        PGIS        0         0         0
# 8792                                        PGIS        0         0         0
# 8794                                        PGIS       -9        -9         0
# 8803                                        PGIS        0         0         0
# 8804                                        PGIS        0         0         0
# 8812                                        PGIS       -9        -9         0
# 8859                                        PGIS        0         0         0
# 8954                                        PGIS        0         0         0
# 9394                                        PGIS       -9        -9         0
# 9434                                        PGIS       -9        -9         0
# 9502                                        PGIS        0         0         0
# 9542                                        PGIS       -9        -9         0
# 9586                                        PGIS       -9        -9         0
# 10088                                       PGIS        0         0         0
# 10196                                       PGIS       -9        -9         0
# 10404                                       PGIS       -9        -9         0
# 11274                                       PGIS        0         0         0
# 11791                                       PGIS       -9        -9         0
# ...                                          ...      ...       ...       ...
# 165436                  START Primary Collection       -9        -9         0
# 165437                  START Primary Collection       -9        -9         0
# 165438                  START Primary Collection        0         0         0
# 165453                  START Primary Collection       -9        -9         0
# 165468                  START Primary Collection       -9        -9         0
# 165488                  START Primary Collection        0         0         0
# 165520                  START Primary Collection       -9        -9         0
# 165521                  START Primary Collection       -9        -9         0
# 165524                  START Primary Collection       -9        -9         0
# 165525                  START Primary Collection       -9        -9         0
# 165526                  START Primary Collection       -9        -9         0
# 165539                  START Primary Collection       -9        -9         0
# 165555                  START Primary Collection       -9        -9         0
# 165592                  START Primary Collection       -9        -9         0
# 165594                  START Primary Collection        0         0         0
# 165611                  START Primary Collection       -9        -9         0
# 165612                  START Primary Collection       -9        -9         0
# 165613                  START Primary Collection       -9        -9         0
# 165614                  START Primary Collection       -9        -9         0
# 165618                  START Primary Collection       -9        -9         0
# 165619                  START Primary Collection       -9        -9         0
# 165634                  START Primary Collection       -9        -9         0
# 165640                  START Primary Collection       -9        -9         0
# 165663                  START Primary Collection       -9        -9         0
# 165681                  START Primary Collection       -9        -9         0
# 165682                  START Primary Collection       -9        -9         0
# 165695                  START Primary Collection       -9        -9         0
# 165697                  START Primary Collection       -9        -9         0
# 165707                  START Primary Collection       -9        -9         0
# 165721                  START Primary Collection       -9        -9         0
#
#         INT_ANY
# 1166          1
# 2656          0
# 3726         -9
# 5171          1
# 7088          0
# 7092         -9
# 7864          0
# 8349          0
# 8489          0
# 8493          0
# 8494          0
# 8701          0
# 8763          0
# 8792          0
# 8794         -9
# 8803          0
# 8804          0
# 8812         -9
# 8859          0
# 8954          0
# 9394         -9
# 9434         -9
# 9502          0
# 9542         -9
# 9586         -9
# 10088         0
# 10196        -9
# 10404        -9
# 11274         0
# 11791        -9
# ...         ...
# 165436       -9
# 165437       -9
# 165438        0
# 165453       -9
# 165468       -9
# 165488        0
# 165520       -9
# 165521       -9
# 165524       -9
# 165525       -9
# 165526       -9
# 165539       -9
# 165555       -9
# 165592       -9
# 165594        0
# 165611       -9
# 165612       -9
# 165613       -9
# 165614       -9
# 165618       -9
# 165619       -9
# 165634       -9
# 165640       -9
# 165663       -9
# 165681       -9
# 165682       -9
# 165695       -9
# 165697       -9
# 165707       -9
# 165721       -9
#
# [10822 rows x 48 columns]

# %%
plt.figure(figsize=(17,20))
plt.title('Attacks In India', fontsize=18)
data[data.country_txt == 'India'].provstate.value_counts().plot(kind='bar');

# %%
plt.figure(figsize=(17,10))
plt.title('Attacks In India : Weapon Types', fontsize=18)
data[data.country_txt == 'India'].weaptype1_txt.value_counts().plot(kind='bar');

# %%
data = data[['country_txt']].copy()
data['event_id'] = data.index

# Calculate the number of attacks
data = data.groupby(['country_txt']).agg(['count'])
data = data.reset_index()
data.columns = ['Country','Attacks']

# Order attacks descending
data = data.sort_values('Attacks', ascending=False)[0:20]
data = data.reset_index()

# Set the color palette in reverse
colors = sns.color_palette('Reds', len(data))
colors.reverse()
plt.figure(figsize=(14.6, 9.0))

# Plot bar chart with index as y values
ax = sns.barplot(data.Attacks, data.index, orient='h', palette=colors)
ax.get_xaxis().set_major_formatter(plt.FuncFormatter(lambda x, loc: "{:,}".format(int(x))))

# Reset the y labels
ax.set_yticklabels(data.Country)
ax.set_xlabel(xlabel='Number of Attacks', fontsize=16)
ax.set_title(label='Top 20 Countries by Total Attacks 1995 - 2017', fontsize=20)
plt.show();
