# %% [markdown]
# # Importing Libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Importing The Data

# %%
data = pd.read_csv("A:/MinorProjectData/globalterror.csv" , encoding = "latin1", low_memory=False )

# %% [markdown]
# # Basic Structure of Data

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 170350 entries, 0 to 170349
# Columns: 135 entries, eventid to related
# dtypes: float64(53), int64(24), object(58)
# memory usage: 137.8+ MB

# %%
data.head(10)
# Out:
#         eventid  iyear  imonth  iday approxdate  extended resolution  country  \
# 0  197000000001   1970       7     2        NaN         0        NaN       58
# 1  197000000002   1970       0     0        NaN         0        NaN      130
# 2  197001000001   1970       1     0        NaN         0        NaN      160
# 3  197001000002   1970       1     0        NaN         0        NaN       78
# 4  197001000003   1970       1     0        NaN         0        NaN      101
# 5  197001010002   1970       1     1        NaN         0        NaN      217
# 6  197001020001   1970       1     2        NaN         0        NaN      218
# 7  197001020002   1970       1     2        NaN         0        NaN      217
# 8  197001020003   1970       1     2        NaN         0        NaN      217
# 9  197001030001   1970       1     3        NaN         0        NaN      217
#
#           country_txt  region   ...     \
# 0  Dominican Republic       2   ...
# ...

# %% [markdown]
# # Checking Missing Or Duplicate Values

# %% [markdown]
# 1.DUPLICATE VALUES

# %%
for x in data.duplicated():
    if x == True:
        print("True")

# %%
# Thus , no duplicate records

# %% [markdown]
# 2.MISSING VALUES

# %%
data.isnull()
# Out:
#         eventid  iyear  imonth   iday  approxdate  extended  resolution  \
# 0         False  False   False  False        True     False        True
# 1         False  False   False  False        True     False        True
# 2         False  False   False  False        True     False        True
# 3         False  False   False  False        True     False        True
# 4         False  False   False  False        True     False        True
# 5         False  False   False  False        True     False        True
# 6         False  False   False  False        True     False        True
# 7         False  False   False  False        True     False        True
# 8         False  False   False  False        True     False        True
# 9         False  False   False  False        True     False        True
# 10        False  False   False  False        True     False        True
# 11        False  False   False  False        True     False        True
# ...

# %% [markdown]
# " Missing Values are present in the dataset "

# %% [markdown]
# 1. CALCULATING PERCENTAGE OF MISSING VALUES IN EACH COLUMN

# %%
count = data.isnull().sum()
percent = round(count/170350*100 , 2)
k = [count , percent]
missing_count = pd.concat(k, axis=1, keys=['Missing_Values','Percent'])
missing_count.sort_values(by='Missing_Values', ascending=False)
# Out:
#                   Missing_Values  Percent
# gsubname3                 170337    99.99
# weapsubtype4_txt          170279    99.96
# weapsubtype4              170279    99.96
# weaptype4                 170276    99.96
# weaptype4_txt             170276    99.96
# claimmode3                170230    99.93
# claimmode3_txt            170230    99.93
# gsubname2                 170201    99.91
# claim3                    170087    99.85
# guncertain3               170085    99.84
# gname3                    170081    99.84
# divert                    170037    99.82
# attacktype3               169976    99.78
# attacktype3_txt           169976    99.78
# ransomnote                169879    99.72
# ransompaidus              169863    99.71
# ransomamtus               169854    99.71
# claimmode2                169818    99.69
# claimmode2_txt            169818    99.69
# ransompaid                169643    99.58
# corp3                     169466    99.48
# ...

# %% [markdown]
# Many columns contain huge percentage of missing data <br>
# Not efficient to handle columns with majority of the entries missing <br>

# %% [markdown]
# 2 . REMOVING COLUMNS WITH MAJORITY OF DATA MISSING

# %%
# Function to remove columns with MORE THAN 50% MISSING VALUES
def drop_missing_columns(cols):
    if data[cols].isnull().sum() > data[cols].count() / 2 :
        del data[cols]

# %%
# Using function for each column in the dataset
for i in data.columns:
    drop_missing_columns(i)

# %% [markdown]
# Remaining Columns after removing other columns

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 170350 entries, 0 to 170349
# Data columns (total 48 columns):
# eventid             170350 non-null int64
# iyear               170350 non-null int64
# imonth              170350 non-null int64
# iday                170350 non-null int64
# extended            170350 non-null int64
# country             170350 non-null int64
# country_txt         170350 non-null object
# region              170350 non-null int64
# region_txt          170350 non-null object
# provstate           155848 non-null object
# city                169904 non-null object
# latitude            165744 non-null float64
# longitude           165744 non-null float64
# specificity         170346 non-null float64
# vicinity            170350 non-null int64
# crit1               170350 non-null int64
# crit2               170350 non-null int64
# crit3               170350 non-null int64
# doubtterr           170350 non-null int64
# ...

# %% [markdown]
# Number of Missing Values <br>
# Such values can be handled without losing efficiency

# %%
data.isnull().sum()
# Out:
# eventid                 0
# iyear                   0
# imonth                  0
# iday                    0
# extended                0
# country                 0
# country_txt             0
# region                  0
# region_txt              0
# provstate           14502
# city                  446
# latitude             4606
# longitude            4606
# specificity             4
# vicinity                0
# crit1                   0
# crit2                   0
# crit3                   0
# doubtterr               0
# multiple                0
# success                 0
# suicide                 0
# attacktype1             0
# attacktype1_txt         0
# targtype1               0
# targtype1_txt           0
# targsubtype1         9345
# targsubtype1_txt     9345
# corp1               42566
# target1               636
# natlty1              1394
# natlty1_txt          1394
# gname                   0
# guncertain1           379
# individual              0
# ...

# %% [markdown]
# # Writing The New Dataset Into A CSV File

# %%
data.to_csv("A:/MinorProjectData/GlobalTerrorCleanPartOne.csv" , encoding ="utf-8")

# %% [markdown]
# The new data in csv only contains the required columns
